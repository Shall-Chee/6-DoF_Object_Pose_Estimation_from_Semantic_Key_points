# %% [markdown]
# Run the next code block. There will be two separate authentications needed. The first will download all extra files from the CIS580 shared drive files. The second connects your google drive to save files to 'cis580-2020-hw8'

# %%
# bootstrap environment into place
from google.colab import auth
auth.authenticate_user()

from googleapiclient.discovery import build
drive_service = build('drive', 'v3')

import io
import os
from googleapiclient.http import MediaIoBaseDownload

def download_file(fn, file_id):
    request = drive_service.files().get_media(fileId=file_id)
    downloaded = io.BytesIO()
    downloader = MediaIoBaseDownload(downloaded, request)
    done = False
    while done is False:
        # _ is a placeholder for a progress object that we ignore.
        # (Our file is small, so we skip reporting progress.)
        _, done = downloader.next_chunk()
    
    downloaded.seek(0)

    folder = fn.split('/')
    if len(folder) > 1:
        os.makedirs(folder[0], exist_ok=True)

    with open(fn, 'wb') as f:
        f.write(downloaded.read())

id_to_fn = {
        '1-1Ehz1QBrjYqfH6SITCbmn6B29CyCPqo': "data/images.npz",
        '1-OWMg8uy2bvuONw_0mmCMaEJBmckvxud': "data/train_data.npz",
        '1-GNpWqe4T1UTWY_QnvzJDU7-WCc1uDIL': "data/valid_data.npz",
        '1-Wk9OoipexkS8BlVR_1_TD3Ay1vgzAl-': "data/kpt.npy",
        '1-R8Ml635hqPaNNDhNUDspEZZJW2AzsnG': "data/misc_data.npz",
        '1-cXm7Q1m7pZQYlUKpCHchHCwbmQDV299': "utils/__init__.py",
        '1-c3vs68eYuBrdaj0Emim46aGVz4xdeUW': "utils/pose_utils.py",
        '1-YX63uppCMtOwxXfQta9z97AihtWQpY8': "utils/plotting.py",
        '1-bViGma06XmSbJGYddfeofFP8LXqi1bQ': "utils/train_options.py",
        '1-8vm2jmtbGpquuw-FHuaBRTz2P7ItrMb': "hourglass.py",
        '1-Pdkc9DMm-d1eJaOuXtJTXrgFsqZCE1W': "dataset.py",
           }

# download all files into the vm
for fid, fn in id_to_fn.items():
    download_file(fn, fid)

# mount the user's google drive into the system
from google.colab import drive
drive.mount('/content/gdrive')
# create folder to write data to
os.makedirs('/content/gdrive/My Drive/cis580-2020-hw8', exist_ok=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# The next code block handles the external library imports.

# %%
from __future__ import division
from __future__ import print_function

import torch
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import make_grid

from hourglass import hg

from dataset import Dataset
from dataset import RandomFlipLR, RandomRescaleBB, RandomRotation,\
                    CropAndPad, LocsToHeatmaps,\
                    ToTensor, Normalize, Denormalize
from utils import TrainOptions, PoseUtils

from tqdm import tqdm
from PIL import Image
import os
from time import time
import numpy as np

# %% [markdown]
# Step 1) The Trainer class contains two locations where you must implement the training step and the test step as specified in the accompanying PDF

# %%
class Trainer(object):

    def __init__(self, options):
        self.options = options
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        train_transform_list = []
        train_transform_list.append(RandomRescaleBB(0.8, 1.2))
        train_transform_list.append(RandomFlipLR())
        train_transform_list.append(RandomRotation(degrees=options.degrees))
        train_transform_list.append(CropAndPad(out_size=(options.crop_size, options.crop_size)))
        train_transform_list.append(LocsToHeatmaps(out_size=(options.heatmap_size, options.heatmap_size)))
        train_transform_list.append(ToTensor())
        train_transform_list.append(Normalize())
        test_transform_list = [CropAndPad(out_size=(options.crop_size, options.crop_size))]
        test_transform_list.append(LocsToHeatmaps(out_size=(options.heatmap_size, options.heatmap_size)))
        test_transform_list.append(ToTensor())
        test_transform_list.append(Normalize())
        self.train_ds = Dataset(is_train=True, transform=transforms.Compose(train_transform_list))
        self.test_ds = Dataset(is_train=False, transform=transforms.Compose(test_transform_list))

        self.model = hg(num_stacks=options.num_stacks, num_blocks=options.num_blocks, num_classes=options.num_classes).to(self.device)
        # define loss function and optimizer
        self.heatmap_loss = torch.nn.MSELoss().to(self.device) # for Global loss
        self.optimizer = torch.optim.RMSprop(self.model.parameters(),
                                             lr = options.lr)


        self.pose_utils = PoseUtils(detection_thresh=options.detection_thresh, dist_thresh=options.dist_thresh)

        self.train_data_loader = DataLoader(self.train_ds, batch_size=options.batch_size,
                                            num_workers=options.num_workers,
                                            pin_memory=True,
                                            shuffle=True)
        self.test_data_loader = DataLoader(self.test_ds, batch_size=options.test_batch_size,
                                           num_workers=options.num_workers,
                                           pin_memory=True,
                                           shuffle=True)

        self.summary_iters = []
        self.losses = []
        self.pcks = []

    def train(self):
        self.total_step_count = 0
        start_time = time()
        for epoch in range(1,self.options.num_epochs+1):
            elapsed_time = time() - start_time
            seconds_per_epoch = elapsed_time / epoch
            remaining_time = (self.options.num_epochs - epoch) * seconds_per_epoch

            print("Epoch %d/%d - Elapsed Time %f - Remaining Time %f" %
                    (epoch, self.options.num_epochs,
                        elapsed_time, remaining_time))

            for step, batch in enumerate(self.train_data_loader):
                self.model.train()
                batch = {k: v.to(self.device) if isinstance(v, torch.Tensor) else v for k,v in batch.items()}
                """
                ADD YOUR CODE FOR THE TRAINING STEP HERE
                You have to name the output of your neural network pred_heatmap_list
                This list contains the output heatmaps for each stack of the Stacked Hourglass model
                Since we are using only 1 stack in this homework, pred_heatmap_list will contain only 1 tensor
                """
                self.optimizer.zero_grad()
                images = batch['image']

                pred_heatmap_list = self.model(images)
                keypoint_heatmaps = batch['keypoint_heatmaps']
                loss = self.heatmap_loss(pred_heatmap_list[-1],keypoint_heatmaps)
                loss.backward()
                self.optimizer.step()

                self.total_step_count += 1
                if self.total_step_count % self.options.summary_steps == 0:
                    self.save_summaries(batch, pred_heatmap_list[-1].detach(), loss.detach(), mode='train')
                if self.total_step_count % self.options.test_steps == 0:
                    self.model.eval()
                    batch = next(iter(self.test_data_loader))
                    batch = {k: v.to(self.device) if isinstance(v, torch.Tensor) else v for k,v in batch.items()}
                    """
                    ADD YOUR CODE FOR THE TEST STEP HERE
                    What you have to do is to perform a forward pass and record the loss and the output
                    """
                    with torch.no_grad():
                      images = batch['image']
                      pred_heatmap_list = self.model(images)
                      keypoint_heatmaps = batch['keypoint_heatmaps']
                      loss = self.heatmap_loss(pred_heatmap_list[-1],keypoint_heatmaps)
                      self.save_summaries(batch, pred_heatmap_list[-1], loss, mode='test')

        checkpoint = {'model': self.model.state_dict()}
        torch.save(checkpoint, '/content/gdrive/My Drive/cis580-2020-hw8/model_checkpoint.pt')

    def save_summaries(self, batch, pred_heatmaps, loss, mode='train'):
        gt_heatmaps = batch['keypoint_heatmaps'].to(self.device)
        pck = self.pose_utils.pck(gt_heatmaps, pred_heatmaps)

        batch = Denormalize()(batch)
        images = batch['image']

        gt_image_keypoints, pred_image_keypoints = self.pose_utils.draw_keypoints_with_labels(images, gt_heatmaps, pred_heatmaps)

        gt_image_keypoints_grid = make_grid(gt_image_keypoints, pad_value=1, nrow=3)
        pred_image_keypoints_grid = make_grid(pred_image_keypoints, pad_value=1, nrow=3)

        pred_heatmaps_grid = make_grid(pred_heatmaps[0,:,:,:].unsqueeze(0).transpose(0,1), pad_value=1, nrow=5)
        pred_heatmaps_grid[pred_heatmaps_grid > 1] = 1
        pred_heatmaps_grid[pred_heatmaps_grid < 0] = 0

        self.losses.append(loss)
        self.pcks.append(pck)
        self.summary_iters.append(self.total_step_count)

        folder = '/content/gdrive/My Drive/cis580-2020-hw8/logs/%d' % self.total_step_count
        os.makedirs(folder, exist_ok=True)

        gt_ikg = Image.fromarray((gt_image_keypoints_grid.cpu().detach().numpy().transpose(1,2,0) * 255.).astype(np.uint8))
        pred_ikg = Image.fromarray((pred_image_keypoints_grid.cpu().detach().numpy().transpose(1,2,0) * 255.).astype(np.uint8))
        pred_hg = Image.fromarray((pred_heatmaps_grid.cpu().detach().numpy().transpose(1,2,0) * 255.).astype(np.uint8))

        gt_ikg.save(os.path.join(folder, mode + '_gt_image_keypoints.jpg'))
        pred_ikg.save(os.path.join(folder, mode + '_pred_image_keypoints.jpg'))
        pred_hg.save(os.path.join(folder, mode + '_pred_heatmaps.jpg'))

# %% [markdown]
# The next block will start the training process. Be sure to run the above block first every time you want to test changes to the code.

# %%
options = TrainOptions().parse_args(["--name=gascan",
                                     "--summary_steps=200",
                                     "--num_epochs=400",
                                     "--test_steps=1000"])
trainer = Trainer(options)
trainer.train()
# Out:
# Epoch 1/400 - Elapsed Time 0.000003 - Remaining Time 0.001046
# Epoch 2/400 - Elapsed Time 10.280808 - Remaining Time 2045.880834
# Epoch 3/400 - Elapsed Time 20.479149 - Remaining Time 2710.074002
# Epoch 4/400 - Elapsed Time 30.413907 - Remaining Time 3010.976798
# Epoch 5/400 - Elapsed Time 40.451516 - Remaining Time 3195.669776
# Epoch 6/400 - Elapsed Time 50.377289 - Remaining Time 3308.108664
# Epoch 7/400 - Elapsed Time 60.605767 - Remaining Time 3402.580946
# Epoch 8/400 - Elapsed Time 70.473635 - Remaining Time 3453.208136
# Epoch 9/400 - Elapsed Time 80.408939 - Remaining Time 3493.321689
# Epoch 10/400 - Elapsed Time 90.704073 - Remaining Time 3537.458864
# Epoch 11/400 - Elapsed Time 100.625975 - Remaining Time 3558.500393
# Epoch 12/400 - Elapsed Time 111.019745 - Remaining Time 3589.638410
# Epoch 13/400 - Elapsed Time 121.340378 - Remaining Time 3612.209709
# Epoch 14/400 - Elapsed Time 131.451203 - Remaining Time 3624.297451
# Epoch 15/400 - Elapsed Time 141.458620 - Remaining Time 3630.771236
# Epoch 16/400 - Elapsed Time 151.386244 - Remaining Time 3633.269846
# Epoch 17/400 - Elapsed Time 161.255875 - Remaining Time 3633.000004
# Epoch 18/400 - Elapsed Time 171.086567 - Remaining Time 3630.837137
# Epoch 19/400 - Elapsed Time 181.101635 - Remaining Time 3631.564360
# Epoch 20/400 - Elapsed Time 191.164436 - Remaining Time 3632.124281
# Epoch 21/400 - Elapsed Time 200.957820 - Remaining Time 3626.810187
# Epoch 22/400 - Elapsed Time 210.817067 - Remaining Time 3622.220517
# Epoch 23/400 - Elapsed Time 221.658134 - Remaining Time 3633.265935
# Epoch 24/400 - Elapsed Time 231.588829 - Remaining Time 3628.224992
# Epoch 25/400 - Elapsed Time 241.312613 - Remaining Time 3619.689192
# Epoch 26/400 - Elapsed Time 251.141559 - Remaining Time 3612.574739
# Epoch 27/400 - Elapsed Time 260.949574 - Remaining Time 3604.970044
# Epoch 28/400 - Elapsed Time 270.744112 - Remaining Time 3597.028923
# Epoch 29/400 - Elapsed Time 280.491916 - Remaining Time 3588.362094
# Epoch 30/400 - Elapsed Time 290.454198 - Remaining Time 3582.268438
# Epoch 31/400 - Elapsed Time 300.261919 - Remaining Time 3574.085418
# Epoch 32/400 - Elapsed Time 310.027815 - Remaining Time 3565.319874
# Epoch 33/400 - Elapsed Time 320.118648 - Remaining Time 3560.107386
# Epoch 34/400 - Elapsed Time 329.989416 - Remaining Time 3552.239011
# Epoch 35/400 - Elapsed Time 339.796495 - Remaining Time 3543.592019
# Epoch 36/400 - Elapsed Time 349.616825 - Remaining Time 3535.014567
# Epoch 37/400 - Elapsed Time 359.814092 - Remaining Time 3530.067985
# Epoch 38/400 - Elapsed Time 369.757291 - Remaining Time 3522.424723
# Epoch 39/400 - Elapsed Time 379.778517 - Remaining Time 3515.385760
# Epoch 40/400 - Elapsed Time 389.728795 - Remaining Time 3507.559155
# Epoch 41/400 - Elapsed Time 399.518764 - Remaining Time 3498.225279
# Epoch 42/400 - Elapsed Time 409.581332 - Remaining Time 3491.193262
# Epoch 43/400 - Elapsed Time 419.526897 - Remaining Time 3483.048887
# Epoch 44/400 - Elapsed Time 430.274502 - Remaining Time 3481.311878
# Epoch 45/400 - Elapsed Time 440.091245 - Remaining Time 3471.830936
# Epoch 46/400 - Elapsed Time 449.782340 - Remaining Time 3461.368445
# Epoch 47/400 - Elapsed Time 459.771376 - Remaining Time 3453.176506
# Epoch 48/400 - Elapsed Time 469.623959 - Remaining Time 3443.909033
# Epoch 49/400 - Elapsed Time 479.384344 - Remaining Time 3433.957242
# Epoch 50/400 - Elapsed Time 489.110932 - Remaining Time 3423.776525
# Epoch 51/400 - Elapsed Time 498.984467 - Remaining Time 3414.619198
# Epoch 52/400 - Elapsed Time 508.709459 - Remaining Time 3404.440226
# Epoch 53/400 - Elapsed Time 518.514974 - Remaining Time 3394.805585
# Epoch 54/400 - Elapsed Time 530.911211 - Remaining Time 3401.764428
# Epoch 55/400 - Elapsed Time 540.919276 - Remaining Time 3393.039092
# Epoch 56/400 - Elapsed Time 551.092241 - Remaining Time 3385.280906
# Epoch 57/400 - Elapsed Time 561.111917 - Remaining Time 3376.515568
# Epoch 58/400 - Elapsed Time 571.041041 - Remaining Time 3367.173037
# Epoch 59/400 - Elapsed Time 580.784041 - Remaining Time 3356.734879
# Epoch 60/400 - Elapsed Time 590.636773 - Remaining Time 3346.941712
# Epoch 61/400 - Elapsed Time 600.619091 - Remaining Time 3337.866750
# Epoch 62/400 - Elapsed Time 610.465949 - Remaining Time 3328.024045
# Epoch 63/400 - Elapsed Time 620.182396 - Remaining Time 3317.483613
# Epoch 64/400 - Elapsed Time 629.947582 - Remaining Time 3307.224803
# Epoch 65/400 - Elapsed Time 640.502961 - Remaining Time 3301.053723
# Epoch 66/400 - Elapsed Time 650.367987 - Remaining Time 3291.256177
# Epoch 67/400 - Elapsed Time 660.379429 - Remaining Time 3282.184324
# Epoch 68/400 - Elapsed Time 670.115069 - Remaining Time 3271.738278
# Epoch 69/400 - Elapsed Time 679.913150 - Remaining Time 3261.612356
# Epoch 70/400 - Elapsed Time 689.688379 - Remaining Time 3251.388074
# Epoch 71/400 - Elapsed Time 699.515315 - Remaining Time 3241.416035
# Epoch 72/400 - Elapsed Time 709.231355 - Remaining Time 3230.942838
# Epoch 73/400 - Elapsed Time 719.101157 - Remaining Time 3221.179157
# Epoch 74/400 - Elapsed Time 728.952705 - Remaining Time 3211.332189
# Epoch 75/400 - Elapsed Time 739.324306 - Remaining Time 3203.738660
# Epoch 76/400 - Elapsed Time 749.132045 - Remaining Time 3193.668190
# Epoch 77/400 - Elapsed Time 758.970331 - Remaining Time 3183.732686
# Epoch 78/400 - Elapsed Time 768.910761 - Remaining Time 3174.221346
# Epoch 79/400 - Elapsed Time 778.681179 - Remaining Time 3164.008334
# Epoch 80/400 - Elapsed Time 788.772429 - Remaining Time 3155.089717
# Epoch 81/400 - Elapsed Time 798.503084 - Remaining Time 3144.722022
# Epoch 82/400 - Elapsed Time 808.245447 - Remaining Time 3134.415272
# Epoch 83/400 - Elapsed Time 818.344968 - Remaining Time 3125.486203
# Epoch 84/400 - Elapsed Time 828.105510 - Remaining Time 3115.254061
# Epoch 85/400 - Elapsed Time 837.963700 - Remaining Time 3105.394888
# Epoch 86/400 - Elapsed Time 848.308918 - Remaining Time 3097.313958
# Epoch 87/400 - Elapsed Time 858.309134 - Remaining Time 3087.939760
# Epoch 88/400 - Elapsed Time 868.150119 - Remaining Time 3077.986785
# Epoch 89/400 - Elapsed Time 877.878891 - Remaining Time 3067.644215
# Epoch 90/400 - Elapsed Time 887.643814 - Remaining Time 3057.439804
# Epoch 91/400 - Elapsed Time 897.642901 - Remaining Time 3048.040182
# Epoch 92/400 - Elapsed Time 907.860818 - Remaining Time 3039.360130
# Epoch 93/400 - Elapsed Time 917.805378 - Remaining Time 3029.744636
# Epoch 94/400 - Elapsed Time 927.746693 - Remaining Time 3020.111575
# Epoch 95/400 - Elapsed Time 937.833491 - Remaining Time 3010.939102
# Epoch 96/400 - Elapsed Time 947.934908 - Remaining Time 3001.793876
# Epoch 97/400 - Elapsed Time 957.810925 - Remaining Time 2991.924850
# Epoch 98/400 - Elapsed Time 967.541430 - Remaining Time 2981.607263
# Epoch 99/400 - Elapsed Time 977.223769 - Remaining Time 2971.155097
# Epoch 100/400 - Elapsed Time 987.180426 - Remaining Time 2961.541277
# Epoch 101/400 - Elapsed Time 997.027767 - Remaining Time 2951.597054
# Epoch 102/400 - Elapsed Time 1006.922950 - Remaining Time 2941.794502
# Epoch 103/400 - Elapsed Time 1016.738440 - Remaining Time 2931.760355
# Epoch 104/400 - Elapsed Time 1026.491467 - Remaining Time 2921.552638
# Epoch 105/400 - Elapsed Time 1036.216429 - Remaining Time 2911.274730
# Epoch 106/400 - Elapsed Time 1046.079871 - Remaining Time 2901.391339
# Epoch 107/400 - Elapsed Time 1058.569118 - Remaining Time 2898.698612
# Epoch 108/400 - Elapsed Time 1068.371793 - Remaining Time 2888.560773
# Epoch 109/400 - Elapsed Time 1078.226617 - Remaining Time 2878.568309
# Epoch 110/400 - Elapsed Time 1087.871025 - Remaining Time 2868.023612
# Epoch 111/400 - Elapsed Time 1097.654555 - Remaining Time 2857.857356
# Epoch 112/400 - Elapsed Time 1107.443069 - Remaining Time 2847.710748
# Epoch 113/400 - Elapsed Time 1117.624685 - Remaining Time 2838.568890
# Epoch 114/400 - Elapsed Time 1127.543624 - Remaining Time 2828.749794
# Epoch 115/400 - Elapsed Time 1137.667026 - Remaining Time 2819.435673
# Epoch 116/400 - Elapsed Time 1147.899631 - Remaining Time 2810.374959
# Epoch 117/400 - Elapsed Time 1158.030651 - Remaining Time 2801.048498
# Epoch 118/400 - Elapsed Time 1167.779953 - Remaining Time 2790.796160
# Epoch 119/400 - Elapsed Time 1177.742035 - Remaining Time 2781.054722
# Epoch 120/400 - Elapsed Time 1187.487178 - Remaining Time 2770.803415
# Epoch 121/400 - Elapsed Time 1197.354088 - Remaining Time 2760.841244
# Epoch 122/400 - Elapsed Time 1207.260935 - Remaining Time 2750.971639
# Epoch 123/400 - Elapsed Time 1217.093667 - Remaining Time 2740.934519
# Epoch 124/400 - Elapsed Time 1227.149638 - Remaining Time 2731.397582
# Epoch 125/400 - Elapsed Time 1237.113489 - Remaining Time 2721.649676
# Epoch 126/400 - Elapsed Time 1246.917708 - Remaining Time 2711.551206
# Epoch 127/400 - Elapsed Time 1257.001875 - Remaining Time 2702.059149
# Epoch 128/400 - Elapsed Time 1267.473144 - Remaining Time 2693.380432
# Epoch 129/400 - Elapsed Time 1277.605489 - Remaining Time 2683.961919
# Epoch 130/400 - Elapsed Time 1287.503460 - Remaining Time 2674.045648
# Epoch 131/400 - Elapsed Time 1297.470125 - Remaining Time 2664.270716
# Epoch 132/400 - Elapsed Time 1307.234273 - Remaining Time 2654.081706
# Epoch 133/400 - Elapsed Time 1317.023182 - Remaining Time 2643.948793
# Epoch 134/400 - Elapsed Time 1326.837046 - Remaining Time 2633.870553
# Epoch 135/400 - Elapsed Time 1336.922339 - Remaining Time 2624.329036
# Epoch 136/400 - Elapsed Time 1346.831262 - Remaining Time 2614.437156
# Epoch 137/400 - Elapsed Time 1356.692904 - Remaining Time 2604.454260
# Epoch 138/400 - Elapsed Time 1366.884999 - Remaining Time 2595.100505
# Epoch 139/400 - Elapsed Time 1376.638916 - Remaining Time 2584.911922
# Epoch 140/400 - Elapsed Time 1386.535336 - Remaining Time 2574.994195
# Epoch 141/400 - Elapsed Time 1396.624486 - Remaining Time 2565.430793
# Epoch 142/400 - Elapsed Time 1406.533472 - Remaining Time 2555.532646
# Epoch 143/400 - Elapsed Time 1416.465117 - Remaining Time 2545.675071
# Epoch 144/400 - Elapsed Time 1426.207640 - Remaining Time 2535.480250
# Epoch 145/400 - Elapsed Time 1436.140462 - Remaining Time 2525.626329
# Epoch 146/400 - Elapsed Time 1445.950291 - Remaining Time 2515.557355
# Epoch 147/400 - Elapsed Time 1455.735345 - Remaining Time 2505.449267
# Epoch 148/400 - Elapsed Time 1465.608192 - Remaining Time 2495.495029
# Epoch 149/400 - Elapsed Time 1475.628216 - Remaining Time 2485.789814
# Epoch 150/400 - Elapsed Time 1485.594009 - Remaining Time 2475.990015
# Epoch 151/400 - Elapsed Time 1495.429988 - Remaining Time 2465.973954
# Epoch 152/400 - Elapsed Time 1505.464066 - Remaining Time 2456.283476
# Epoch 153/400 - Elapsed Time 1515.176750 - Remaining Time 2446.069655
# Epoch 154/400 - Elapsed Time 1525.056589 - Remaining Time 2436.129357
# Epoch 155/400 - Elapsed Time 1534.815419 - Remaining Time 2425.998565
# Epoch 156/400 - Elapsed Time 1544.697482 - Remaining Time 2416.065293
# Epoch 157/400 - Elapsed Time 1554.491894 - Remaining Time 2405.997007
# Epoch 158/400 - Elapsed Time 1564.314419 - Remaining Time 2395.975249
# Epoch 159/400 - Elapsed Time 1576.869797 - Remaining Time 2390.098245
# Epoch 160/400 - Elapsed Time 1586.921205 - Remaining Time 2380.381807
# Epoch 161/400 - Elapsed Time 1596.668854 - Remaining Time 2370.210286
# Epoch 162/400 - Elapsed Time 1606.455602 - Remaining Time 2360.101440
# Epoch 163/400 - Elapsed Time 1616.251077 - Remaining Time 2350.009234
# Epoch 164/400 - Elapsed Time 1626.353014 - Remaining Time 2340.361655
# Epoch 165/400 - Elapsed Time 1636.108876 - Remaining Time 2330.215671
# Epoch 166/400 - Elapsed Time 1646.156570 - Remaining Time 2320.485768
# Epoch 167/400 - Elapsed Time 1656.466796 - Remaining Time 2311.118344
# Epoch 168/400 - Elapsed Time 1666.443593 - Remaining Time 2301.279248
# Epoch 169/400 - Elapsed Time 1676.164825 - Remaining Time 2291.089199
# Epoch 170/400 - Elapsed Time 1686.170359 - Remaining Time 2281.289309
# Epoch 171/400 - Elapsed Time 1696.128332 - Remaining Time 2271.423322
# Epoch 172/400 - Elapsed Time 1705.908953 - Remaining Time 2261.321171
# Epoch 173/400 - Elapsed Time 1715.816764 - Remaining Time 2251.389627
# Epoch 174/400 - Elapsed Time 1725.473779 - Remaining Time 2241.132610
# Epoch 175/400 - Elapsed Time 1735.405405 - Remaining Time 2231.235521
# Epoch 176/400 - Elapsed Time 1745.206098 - Remaining Time 2221.171398
# Epoch 177/400 - Elapsed Time 1754.971902 - Remaining Time 2211.066295
# Epoch 178/400 - Elapsed Time 1764.704346 - Remaining Time 2200.923397
# Epoch 179/400 - Elapsed Time 1774.428983 - Remaining Time 2190.775448
# Epoch 180/400 - Elapsed Time 1784.529343 - Remaining Time 2181.091419
# Epoch 181/400 - Elapsed Time 1794.227071 - Remaining Time 2170.915627
# Epoch 182/400 - Elapsed Time 1804.005354 - Remaining Time 2160.841578
# Epoch 183/400 - Elapsed Time 1813.883437 - Remaining Time 2150.889103
# Epoch 184/400 - Elapsed Time 1823.687883 - Remaining Time 2140.850993
# Epoch 185/400 - Elapsed Time 1833.588459 - Remaining Time 2130.927129
# Epoch 186/400 - Elapsed Time 1843.340353 - Remaining Time 2120.832449
# Epoch 187/400 - Elapsed Time 1853.270555 - Remaining Time 2110.944535
# Epoch 188/400 - Elapsed Time 1863.256612 - Remaining Time 2101.119158
# Epoch 189/400 - Elapsed Time 1872.950804 - Remaining Time 2090.966241
# Epoch 190/400 - Elapsed Time 1882.716694 - Remaining Time 2080.897399
# Epoch 191/400 - Elapsed Time 1893.097190 - Remaining Time 2071.504255
# Epoch 192/400 - Elapsed Time 1903.158265 - Remaining Time 2061.754787
# Epoch 193/400 - Elapsed Time 1913.058068 - Remaining Time 2051.829120
# Epoch 194/400 - Elapsed Time 1923.266414 - Remaining Time 2042.231346
# Epoch 195/400 - Elapsed Time 1933.225109 - Remaining Time 2032.364859
# Epoch 196/400 - Elapsed Time 1943.005802 - Remaining Time 2022.312161
# Epoch 197/400 - Elapsed Time 1952.735380 - Remaining Time 2012.209554
# Epoch 198/400 - Elapsed Time 1962.516191 - Remaining Time 2002.162983
# Epoch 199/400 - Elapsed Time 1972.261516 - Remaining Time 1992.083239
# Epoch 200/400 - Elapsed Time 1982.323709 - Remaining Time 1982.323709
# Epoch 201/400 - Elapsed Time 1992.305923 - Remaining Time 1972.481983
# Epoch 202/400 - Elapsed Time 2002.205808 - Remaining Time 1962.558168
# Epoch 203/400 - Elapsed Time 2012.002091 - Remaining Time 1952.534049
# Epoch 204/400 - Elapsed Time 2021.842530 - Remaining Time 1942.554587
# Epoch 205/400 - Elapsed Time 2031.722950 - Remaining Time 1932.614514
# Epoch 206/400 - Elapsed Time 2041.555590 - Remaining Time 1922.630022
# Epoch 207/400 - Elapsed Time 2051.336675 - Remaining Time 1912.598929
# Epoch 208/400 - Elapsed Time 2061.058907 - Remaining Time 1902.515914
# Epoch 209/400 - Elapsed Time 2070.831931 - Remaining Time 1892.482770
# Epoch 210/400 - Elapsed Time 2080.650310 - Remaining Time 1882.493137
# Epoch 211/400 - Elapsed Time 2090.415621 - Remaining Time 1872.457594
# Epoch 212/400 - Elapsed Time 2103.037936 - Remaining Time 1864.958170
# Epoch 213/400 - Elapsed Time 2112.954801 - Remaining Time 1855.035435
# Epoch 214/400 - Elapsed Time 2122.703914 - Remaining Time 1844.966953
# Epoch 215/400 - Elapsed Time 2132.635818 - Remaining Time 1835.058727
# Epoch 216/400 - Elapsed Time 2142.510181 - Remaining Time 1825.101265
# Epoch 217/400 - Elapsed Time 2152.330563 - Remaining Time 1815.099046
# Epoch 218/400 - Elapsed Time 2162.020356 - Remaining Time 1804.989471
# Epoch 219/400 - Elapsed Time 2171.838788 - Remaining Time 1794.990049
# Epoch 220/400 - Elapsed Time 2181.557942 - Remaining Time 1784.911043
# Epoch 221/400 - Elapsed Time 2191.581115 - Remaining Time 1775.081537
# Epoch 222/400 - Elapsed Time 2201.356617 - Remaining Time 1765.051702
# Epoch 223/400 - Elapsed Time 2212.090773 - Remaining Time 1755.785053
# Epoch 224/400 - Elapsed Time 2221.908468 - Remaining Time 1745.785225
# Epoch 225/400 - Elapsed Time 2231.649401 - Remaining Time 1735.727312
# Epoch 226/400 - Elapsed Time 2241.547582 - Remaining Time 1725.793271
# Epoch 227/400 - Elapsed Time 2251.360120 - Remaining Time 1715.794276
# Epoch 228/400 - Elapsed Time 2261.047076 - Remaining Time 1705.702180
# Epoch 229/400 - Elapsed Time 2270.826485 - Remaining Time 1695.682659
# Epoch 230/400 - Elapsed Time 2280.582072 - Remaining Time 1685.647618
# Epoch 231/400 - Elapsed Time 2290.429417 - Remaining Time 1675.682128
# Epoch 232/400 - Elapsed Time 2300.239560 - Remaining Time 1665.690716
# Epoch 233/400 - Elapsed Time 2310.466304 - Remaining Time 1655.999454
# Epoch 234/400 - Elapsed Time 2320.487521 - Remaining Time 1646.157814
# Epoch 235/400 - Elapsed Time 2330.337455 - Remaining Time 1636.194383
# Epoch 236/400 - Elapsed Time 2340.099223 - Remaining Time 1626.170646
# Epoch 237/400 - Elapsed Time 2350.078595 - Remaining Time 1616.298780
# Epoch 238/400 - Elapsed Time 2359.783713 - Remaining Time 1606.239334
# Epoch 239/400 - Elapsed Time 2369.562707 - Remaining Time 1596.232618
# Epoch 240/400 - Elapsed Time 2379.165314 - Remaining Time 1586.110210
# Epoch 241/400 - Elapsed Time 2388.875972 - Remaining Time 1576.063400
# Epoch 242/400 - Elapsed Time 2398.688573 - Remaining Time 1566.085928
# Epoch 243/400 - Elapsed Time 2408.417257 - Remaining Time 1556.055594
# Epoch 244/400 - Elapsed Time 2419.106880 - Remaining Time 1546.642104
# Epoch 245/400 - Elapsed Time 2428.951504 - Remaining Time 1536.683605
# Epoch 246/400 - Elapsed Time 2438.769339 - Remaining Time 1526.709261
# Epoch 247/400 - Elapsed Time 2448.424603 - Remaining Time 1516.635483
# Epoch 248/400 - Elapsed Time 2458.287412 - Remaining Time 1506.692285
# Epoch 249/400 - Elapsed Time 2468.214556 - Remaining Time 1496.788747
# Epoch 250/400 - Elapsed Time 2478.200167 - Remaining Time 1486.920100
# Epoch 251/400 - Elapsed Time 2488.339665 - Remaining Time 1477.141873
# Epoch 252/400 - Elapsed Time 2498.400442 - Remaining Time 1467.314546
# Epoch 253/400 - Elapsed Time 2508.182970 - Remaining Time 1457.323702
# Epoch 254/400 - Elapsed Time 2518.438920 - Remaining Time 1447.606623
# Epoch 255/400 - Elapsed Time 2528.233530 - Remaining Time 1437.622988
# Epoch 256/400 - Elapsed Time 2538.184492 - Remaining Time 1427.728777
# Epoch 257/400 - Elapsed Time 2548.006882 - Remaining Time 1417.762584
# Epoch 258/400 - Elapsed Time 2557.800362 - Remaining Time 1407.781594
# Epoch 259/400 - Elapsed Time 2567.677624 - Remaining Time 1397.847664
# Epoch 260/400 - Elapsed Time 2577.367948 - Remaining Time 1387.813511
# Epoch 261/400 - Elapsed Time 2587.056823 - Remaining Time 1377.781220
# Epoch 262/400 - Elapsed Time 2596.840670 - Remaining Time 1367.801574
# Epoch 263/400 - Elapsed Time 2606.585009 - Remaining Time 1357.802837
# Epoch 264/400 - Elapsed Time 2616.539757 - Remaining Time 1347.914420
# Epoch 265/400 - Elapsed Time 2629.543087 - Remaining Time 1339.578554
# Epoch 266/400 - Elapsed Time 2639.248900 - Remaining Time 1329.546438
# Epoch 267/400 - Elapsed Time 2649.012382 - Remaining Time 1319.545494
# Epoch 268/400 - Elapsed Time 2658.834636 - Remaining Time 1309.575269
# Epoch 269/400 - Elapsed Time 2668.870555 - Remaining Time 1299.710196
# Epoch 270/400 - Elapsed Time 2678.688947 - Remaining Time 1289.739123
# Epoch 271/400 - Elapsed Time 2688.639977 - Remaining Time 1279.832314
# Epoch 272/400 - Elapsed Time 2698.454710 - Remaining Time 1269.861040
# Epoch 273/400 - Elapsed Time 2708.252801 - Remaining Time 1259.883171
# Epoch 274/400 - Elapsed Time 2718.134312 - Remaining Time 1249.944976
# Epoch 275/400 - Elapsed Time 2728.218679 - Remaining Time 1240.099400
# Epoch 276/400 - Elapsed Time 2738.058125 - Remaining Time 1230.142056
# Epoch 277/400 - Elapsed Time 2748.272613 - Remaining Time 1220.352099
# Epoch 278/400 - Elapsed Time 2758.290999 - Remaining Time 1210.473028
# Epoch 279/400 - Elapsed Time 2768.092597 - Remaining Time 1200.498940
# Epoch 280/400 - Elapsed Time 2777.930370 - Remaining Time 1190.541587
# Epoch 281/400 - Elapsed Time 2787.808103 - Remaining Time 1180.602008
# Epoch 282/400 - Elapsed Time 2798.101135 - Remaining Time 1170.836645
# Epoch 283/400 - Elapsed Time 2807.835551 - Remaining Time 1160.836606
# Epoch 284/400 - Elapsed Time 2817.702375 - Remaining Time 1150.892520
# Epoch 285/400 - Elapsed Time 2827.482068 - Remaining Time 1140.913817
# Epoch 286/400 - Elapsed Time 2837.869646 - Remaining Time 1131.178810
# Epoch 287/400 - Elapsed Time 2847.970882 - Remaining Time 1121.326514
# Epoch 288/400 - Elapsed Time 2857.824928 - Remaining Time 1111.376361
# Epoch 289/400 - Elapsed Time 2868.098012 - Remaining Time 1101.587818
# Epoch 290/400 - Elapsed Time 2877.945402 - Remaining Time 1091.634463
# Epoch 291/400 - Elapsed Time 2887.866997 - Remaining Time 1081.709631
# Epoch 292/400 - Elapsed Time 2897.752534 - Remaining Time 1071.771485
# Epoch 293/400 - Elapsed Time 2907.815156 - Remaining Time 1061.898368
# Epoch 294/400 - Elapsed Time 2917.667161 - Remaining Time 1051.948024
# Epoch 295/400 - Elapsed Time 2927.608662 - Remaining Time 1042.030202
# Epoch 296/400 - Elapsed Time 2937.737966 - Remaining Time 1032.178204
# Epoch 297/400 - Elapsed Time 2947.535422 - Remaining Time 1022.209254
# Epoch 298/400 - Elapsed Time 2957.670490 - Remaining Time 1012.357013
# Epoch 299/400 - Elapsed Time 2967.895380 - Remaining Time 1002.533222
# Epoch 300/400 - Elapsed Time 2977.943586 - Remaining Time 992.647862
# Epoch 301/400 - Elapsed Time 2987.694586 - Remaining Time 982.663668
# Epoch 302/400 - Elapsed Time 2997.727172 - Remaining Time 972.772393
# Epoch 303/400 - Elapsed Time 3007.543110 - Remaining Time 962.810831
# Epoch 304/400 - Elapsed Time 3017.358014 - Remaining Time 952.849899
# Epoch 305/400 - Elapsed Time 3027.461225 - Remaining Time 942.979726
# Epoch 306/400 - Elapsed Time 3037.397412 - Remaining Time 933.056721
# Epoch 307/400 - Elapsed Time 3047.627004 - Remaining Time 923.222513
# Epoch 308/400 - Elapsed Time 3057.621099 - Remaining Time 913.315393
# Epoch 309/400 - Elapsed Time 3067.342742 - Remaining Time 903.327474
# Epoch 310/400 - Elapsed Time 3077.079973 - Remaining Time 893.345798
# Epoch 311/400 - Elapsed Time 3086.931864 - Remaining Time 883.398508
# Epoch 312/400 - Elapsed Time 3096.823627 - Remaining Time 873.463074
# Epoch 313/400 - Elapsed Time 3106.670887 - Remaining Time 863.515550
# Epoch 314/400 - Elapsed Time 3116.667318 - Remaining Time 853.609520
# Epoch 315/400 - Elapsed Time 3126.720903 - Remaining Time 843.718339
# Epoch 316/400 - Elapsed Time 3136.633659 - Remaining Time 833.788694
# Epoch 317/400 - Elapsed Time 3149.480248 - Remaining Time 824.627321
# Epoch 318/400 - Elapsed Time 3159.253820 - Remaining Time 814.650356
# Epoch 319/400 - Elapsed Time 3169.373915 - Remaining Time 804.762655
# Epoch 320/400 - Elapsed Time 3179.227243 - Remaining Time 794.806811
# Epoch 321/400 - Elapsed Time 3188.964737 - Remaining Time 784.823097
# Epoch 322/400 - Elapsed Time 3198.904530 - Remaining Time 774.889917
# Epoch 323/400 - Elapsed Time 3208.637371 - Remaining Time 764.907361
# Epoch 324/400 - Elapsed Time 3218.812905 - Remaining Time 755.030188
# Epoch 325/400 - Elapsed Time 3228.947027 - Remaining Time 745.141622
# Epoch 326/400 - Elapsed Time 3238.922614 - Remaining Time 735.215563
# Epoch 327/400 - Elapsed Time 3248.656170 - Remaining Time 725.235169
# Epoch 328/400 - Elapsed Time 3258.883361 - Remaining Time 715.364640
# Epoch 329/400 - Elapsed Time 3268.883609 - Remaining Time 705.442967
# Epoch 330/400 - Elapsed Time 3278.812318 - Remaining Time 695.505643
# Epoch 331/400 - Elapsed Time 3288.787362 - Remaining Time 685.578030
# Epoch 332/400 - Elapsed Time 3298.590223 - Remaining Time 675.614865
# Epoch 333/400 - Elapsed Time 3308.347074 - Remaining Time 665.643405
# Epoch 334/400 - Elapsed Time 3318.221318 - Remaining Time 655.696428
# Epoch 335/400 - Elapsed Time 3328.306614 - Remaining Time 645.790835
# Epoch 336/400 - Elapsed Time 3338.316228 - Remaining Time 635.869758
# Epoch 337/400 - Elapsed Time 3348.481662 - Remaining Time 625.977284
# Epoch 338/400 - Elapsed Time 3358.563297 - Remaining Time 616.067824
# Epoch 339/400 - Elapsed Time 3368.338187 - Remaining Time 606.102152
# Epoch 340/400 - Elapsed Time 3378.248344 - Remaining Time 596.161473
# Epoch 341/400 - Elapsed Time 3388.440139 - Remaining Time 586.269701
# Epoch 342/400 - Elapsed Time 3398.282893 - Remaining Time 576.316982
# Epoch 343/400 - Elapsed Time 3408.275476 - Remaining Time 566.389802
# Epoch 344/400 - Elapsed Time 3418.442849 - Remaining Time 556.490696
# Epoch 345/400 - Elapsed Time 3428.249998 - Remaining Time 546.532608
# Epoch 346/400 - Elapsed Time 3438.234942 - Remaining Time 536.603141
# Epoch 347/400 - Elapsed Time 3447.923160 - Remaining Time 526.628033
# Epoch 348/400 - Elapsed Time 3457.740259 - Remaining Time 516.673832
# Epoch 349/400 - Elapsed Time 3468.032090 - Remaining Time 506.789790
# Epoch 350/400 - Elapsed Time 3477.956788 - Remaining Time 496.850970
# Epoch 351/400 - Elapsed Time 3488.180500 - Remaining Time 486.953973
# Epoch 352/400 - Elapsed Time 3498.270628 - Remaining Time 477.036904
# Epoch 353/400 - Elapsed Time 3508.068455 - Remaining Time 467.079936
# Epoch 354/400 - Elapsed Time 3517.961808 - Remaining Time 457.136280
# Epoch 355/400 - Elapsed Time 3527.772162 - Remaining Time 447.182387
# Epoch 356/400 - Elapsed Time 3537.607314 - Remaining Time 437.232365
# Epoch 357/400 - Elapsed Time 3547.453934 - Remaining Time 427.284367
# Epoch 358/400 - Elapsed Time 3557.303204 - Remaining Time 417.337247
# Epoch 359/400 - Elapsed Time 3567.447805 - Remaining Time 407.424401
# Epoch 360/400 - Elapsed Time 3577.505419 - Remaining Time 397.500602
# Epoch 361/400 - Elapsed Time 3587.261694 - Remaining Time 387.543507
# Epoch 362/400 - Elapsed Time 3596.977348 - Remaining Time 377.583258
# Epoch 363/400 - Elapsed Time 3606.745363 - Remaining Time 367.629693
# Epoch 364/400 - Elapsed Time 3616.609952 - Remaining Time 357.686699
# Epoch 365/400 - Elapsed Time 3626.660436 - Remaining Time 347.761960
# Epoch 366/400 - Elapsed Time 3636.655150 - Remaining Time 337.831353
# Epoch 367/400 - Elapsed Time 3647.573114 - Remaining Time 327.983414
# Epoch 368/400 - Elapsed Time 3657.646260 - Remaining Time 318.056197
# Epoch 369/400 - Elapsed Time 3667.367135 - Remaining Time 308.098594
# Epoch 370/400 - Elapsed Time 3679.861598 - Remaining Time 298.367157
# Epoch 371/400 - Elapsed Time 3690.056608 - Remaining Time 288.441083
# Epoch 372/400 - Elapsed Time 3699.970213 - Remaining Time 278.492382
# Epoch 373/400 - Elapsed Time 3709.868890 - Remaining Time 268.542788
# Epoch 374/400 - Elapsed Time 3719.814978 - Remaining Time 258.596763
# Epoch 375/400 - Elapsed Time 3729.550325 - Remaining Time 248.636688
# Epoch 376/400 - Elapsed Time 3739.583510 - Remaining Time 238.696820
# Epoch 377/400 - Elapsed Time 3749.284801 - Remaining Time 228.736208
# Epoch 378/400 - Elapsed Time 3759.346521 - Remaining Time 218.797946
# Epoch 379/400 - Elapsed Time 3769.167695 - Remaining Time 208.845703
# Epoch 380/400 - Elapsed Time 3779.273767 - Remaining Time 198.909146
# Epoch 381/400 - Elapsed Time 3789.038580 - Remaining Time 188.954680
# Epoch 382/400 - Elapsed Time 3799.039361 - Remaining Time 179.012326
# Epoch 383/400 - Elapsed Time 3808.810545 - Remaining Time 169.059476
# Epoch 384/400 - Elapsed Time 3818.693881 - Remaining Time 159.112245
# Epoch 385/400 - Elapsed Time 3828.454390 - Remaining Time 149.160561
# Epoch 386/400 - Elapsed Time 3838.596123 - Remaining Time 139.223694
# Epoch 387/400 - Elapsed Time 3848.462330 - Remaining Time 129.276512
# Epoch 388/400 - Elapsed Time 3858.264010 - Remaining Time 119.327753
# Epoch 389/400 - Elapsed Time 3868.142115 - Remaining Time 109.381911
# Epoch 390/400 - Elapsed Time 3878.193589 - Remaining Time 99.440861
# Epoch 391/400 - Elapsed Time 3888.167182 - Remaining Time 89.497454
# Epoch 392/400 - Elapsed Time 3898.053973 - Remaining Time 79.552122
# Epoch 393/400 - Elapsed Time 3907.852781 - Remaining Time 69.605520
# Epoch 394/400 - Elapsed Time 3917.603227 - Remaining Time 59.658932
# Epoch 395/400 - Elapsed Time 3927.503287 - Remaining Time 49.715231
# Epoch 396/400 - Elapsed Time 3937.359016 - Remaining Time 39.771303
# Epoch 397/400 - Elapsed Time 3947.097691 - Remaining Time 29.826935
# Epoch 398/400 - Elapsed Time 3956.890632 - Remaining Time 19.883873
# Epoch 399/400 - Elapsed Time 3967.004717 - Remaining Time 9.942368
# Epoch 400/400 - Elapsed Time 3976.940106 - Remaining Time 0.000000

# %% [markdown]
# The next block will run prediction on the test set and save the output detections

# %%
from __future__ import division
from __future__ import print_function

import numpy as np
import torch
from torch.utils.data import DataLoader
from torchvision import transforms

from hourglass import hg

from dataset import Dataset
from dataset import CropAndPad, LocsToHeatmaps, ToTensor, Normalize
from tqdm import tqdm

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = hg(num_stacks=1, num_blocks=1, num_classes=10).to(device)
checkpoint = torch.load('/content/gdrive/My Drive/cis580-2020-hw8/model_checkpoint.pt')
model.load_state_dict(checkpoint['model'])
transform_list = [CropAndPad(out_size=(256, 256))]
transform_list.append(LocsToHeatmaps(out_size=(64,64)))
transform_list.append(ToTensor())
transform_list.append(Normalize())
test_ds = Dataset(is_train=False, transform=transforms.Compose(transform_list))
data_loader = DataLoader(test_ds, batch_size=1, pin_memory=True, shuffle=False)
predicted_heatmaps = np.zeros((len(test_ds), 10, 64, 64))
for i, batch in enumerate(tqdm(data_loader)):
    model.eval()
    images = batch['image'].to(device)
    with torch.no_grad():
        pred_heatmap_list = model(images)
    pred_heatmaps = pred_heatmap_list[-1]
    predicted_heatmaps[i,:,:,:] = pred_heatmaps[0,:,:,:].cpu().numpy()
np.save('/content/gdrive/My Drive/cis580-2020-hw8/detections.npy', predicted_heatmaps)
# Out:
# 100%|██████████| 27/27 [00:01<00:00, 26.87it/s]

# %% [markdown]
# Import the external and given functions for step 2

# %%
import numpy as np
import torch
import torch.nn as nn
import cv2
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import os
from os.path import join
from utils import plot_mesh

"""
Convert axis-angle representation to a 3x3 rotation matrix
"""
class Rodrigues(torch.autograd.Function):
    @staticmethod
    def forward(self, inp):
        pose = inp.detach().cpu().numpy()
        rotm, part_jacob = cv2.Rodrigues(pose)
        self.jacob = torch.Tensor(np.transpose(part_jacob)).contiguous()
        rotation_matrix = torch.Tensor(rotm.ravel())
        return rotation_matrix.view(3,3)

    @staticmethod
    def backward(self, grad_output):
        grad_output = grad_output.view(1,-1)
        grad_input = torch.mm(grad_output, self.jacob)
        grad_input = grad_input.view(-1)
        return grad_input
"""
This is the function you should call to convert fom axis-angle to a rotation matrix
Example usage:
    aa = torch.zeros(3)
    R = rodrigues(aa)
"""
rodrigues = Rodrigues.apply

# %% [markdown]
# Step 2) Implement pose_optimization and heatmaps_to_locs as specified by the accompanying PDF

# %%
"""
YOU NEED TO IMPLEMENT THIS
Input: image, mesh vertices, mesh faces, detected 2d keypoints, keypoint confidences, 3D keypoint coordinates in the canonical position, intrinsic camera matrix
Output: R, t
"""
def pose_optimization(img, vertices, faces, keypoints_2d, conf, keypoints_3d, K):
    # Send variables to GPU
    device = keypoints_2d.device
    keypoints_3d = keypoints_3d.to(device)
    K = K.to(device)
    r = torch.rand(3, requires_grad=True, device=device) # rotation in axis-angle representation
    t = torch.rand(3 ,requires_grad=True, device=device)
    d = conf.sqrt()[:, None]
    # 2D keypoints in normalized coordinates
    norm_keypoints_2d = torch.matmul(K.inverse(), torch.cat((keypoints_2d, torch.ones(keypoints_2d.shape[0],1, device=device)), dim=-1).t()).t()[:,:-1]
    # set up optimizer
    optimizer = torch.optim.Adam([r,t], lr=1e-2)

    # converge check
    converged = False
    rel_tol = 1e-5
    loss_old = 100

    while not converged:
      # convert axis-angle to rotation matrix
      optimizer.zero_grad()
      R = rodrigues(r)
      # 1) Compute projected keypoints based on current estimate of R and t 
      projected_keypoints = R@keypoints_3d.T + t[:,None]
      proj_keypoints = (projected_keypoints/projected_keypoints[2]).T


      # 2) Compute error (based on distance between projected keypoints and detected keypoints)
      coor = (norm_keypoints_2d-proj_keypoints[:, :2])
      error = ((coor*d)**2).sum()  #get sum

      # 3) Update based on error
      error.backward()
      optimizer.step()

      # 4) Check for convergence
      if abs(error.detach()-loss_old)/loss_old > rel_tol:
        loss_old = error.detach()
      else:
        converged = True
      # pass # IMPLEMENT THE ABOVE

    R = rodrigues(r)
    plt.figure()
    plot_mesh(img, vertices, faces, R.detach().cpu().numpy(), t.detach().cpu().numpy()[:,None], K.detach().cpu().numpy())
    # print(proj_keypoints.shape)
    pk = torch.matmul(K, torch.cat((proj_keypoints[:, :2], torch.ones(proj_keypoints.shape[0], 1, device=device)), dim=-1).t()).t()
    pk = pk.detach().cpu().numpy()
    plt.scatter(pk[:,0], pk[:,1], color='r')
    plt.show()
    return rodrigues(r)[0].detach(), t.detach()

"""
YOU NEED TO IMPLEMENT THIS
Convert heatmaps to 2D locations
Input: Nx10x64x64 keypoint heatmaps
Output: Nx10x3 keypoint locations and detection confidence (magnitude of the highest activation)
"""
def heatmaps_to_locs(heatmaps):
    # pass
    heatmaps = heatmaps.numpy()
    N = heatmaps.shape[0]
    loc = np.zeros((N,10,3))
    for i in range(0,N):
      hetmaps_i = heatmaps[i,:,:,:]
      for j in range(0,10):
        ind = np.unravel_index(np.argmax(hetmaps_i[j,:,:]),hetmaps_i[j,:,:].shape)
        loc[i,j,0] = ind[1]
        loc[i,j,1] = ind[0]
        loc[i,j,2] = np.argmax(hetmaps_i[j,:,:])
    return torch.from_numpy(loc.astype('float32'))

# %% [markdown]
# The next block will start the pose optimization process. Be sure to run the above block first every time you want to test changes to the code.

# %%
data = np.load('data/misc_data.npz')
K = torch.from_numpy(data['K']).float()
S = torch.from_numpy(np.load('data/kpt.npy'))
vertices = data['vertices']
faces = data['faces']

dataset = np.load('data/valid_data.npz')
imgnames = dataset['imgname']
scales = torch.from_numpy(dataset['scale']).float()[:,None]
centers = torch.from_numpy(dataset['center']).float()
# detections.npy contains the detections saved after training your model and running predict.py
heatmaps = torch.from_numpy(np.load('/content/gdrive/My Drive/cis580-2020-hw8/detections.npy'))

keypoint_locs = heatmaps_to_locs(heatmaps)

# Compute detected 2D keypoint locations in the original image
ul_corner = centers - scales * 100
keypoint_locs[:,:,:-1] *= scales[:,:,None]*200 / 64
keypoint_locs[:,:,:-1] += ul_corner[:,None,:]

images = np.load('data/images.npz')

os.makedirs('/content/gdrive/My Drive/cis580-2020-hw8/pose_optimization', exist_ok=True)
for i in range(len(heatmaps)):
    img_name = imgnames[i].decode('utf-8')
    print("Processing ", img_name)
    # Fixes incorrect naming scheme
    img = images[img_name]
    pose_optimization(img, vertices, faces, keypoint_locs[i,:,:-1], keypoint_locs[i,:,-1], S, K)
    plt.savefig('/content/gdrive/My Drive/cis580-2020-hw8/pose_optimization/%s' % img_name, dpi=300)
    plt.close('all')
# Out:
# Processing  train_148.jpg
# Processing  train_160.jpg
# Processing  train_80.jpg
# Processing  train_181.jpg
# Processing  train_176.jpg
# Processing  train_2.jpg
# Processing  train_155.jpg
# Processing  train_136.jpg
# Processing  train_4.jpg
# Processing  train_18.jpg
# Processing  train_106.jpg
# Processing  train_90.jpg
# Processing  train_25.jpg
# Processing  train_116.jpg
# Processing  train_190.jpg
# Processing  train_177.jpg
# Processing  train_52.jpg
# Processing  train_191.jpg
# Processing  train_13.jpg
# Processing  train_9.jpg
# Processing  train_81.jpg
# Processing  train_21.jpg
# Processing  train_72.jpg
# Processing  train_144.jpg
# Processing  train_10.jpg
# Processing  train_12.jpg
# Processing  train_140.jpg
